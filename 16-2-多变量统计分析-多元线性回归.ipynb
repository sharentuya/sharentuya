# %%
import pandas as pd

# 加载数据
file_path = R'data\多元回归分析演示数据.xlsx'
数据表 = pd.read_excel(file_path)

# 显示数据的前几行以进行初步检查
数据表.head()
# Out:
#    福利措施  同侪关系  适应学习  创新学习  知识获取  知识流通  知识创新  财务控管  顾客认同  内部运作  学习成长  组织效能
# 0     7     8     7     5     9     8     6     5     5     5     5    20
# 1    11    10    17    13    15     7     4     5     5     5     5    20
# 2     9    10     7     8    20    16    13     6    10     6     5    27
# 3    12    14    14     9    19    14     4     5    12     7     5    29
# 4    12    13     7    13    22    18    14     5     5    10     9    29

# %%
import statsmodels.api as sm
# 使用指定的五个变量作为自变量进行多元线性回归分析
specified_variables = ['知识获取', '内部运作', '适应学习', '学习成长', '知识创新','创新学习','同侪关系']
X_specified = 数据表[specified_variables]
y = 数据表['组织效能']  # 因变量

# 多元线性回归
X_specified_with_constant = sm.add_constant(X_specified)  
model_specified = sm.OLS(y, X_specified_with_constant).fit()

# 显示回归结果
model_specified_summary = model_specified.summary()
model_specified_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   组织效能   R-squared:                       0.922
# Model:                            OLS   Adj. R-squared:                  0.921
# Method:                 Least Squares   F-statistic:                     2007.
# Date:                Thu, 14 Dec 2023   Prob (F-statistic):               0.00
# Time:                        11:18:33   Log-Likelihood:                -3192.9
# No. Observations:                1200   AIC:                             6402.
# Df Residuals:                    1192   BIC:                             6443.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.5848      0.621      5.768      0.000       2.366       4.804
# 知识获取           0.0497      0.031      1.600      0.110      -0.011       0.111
# 内部运作           2.1400      0.054     39.952      0.000       2.035       2.245
# 适应学习           0.1177      0.037      3.146      0.002       0.044       0.191
# 学习成长           1.2957      0.050     25.660      0.000       1.197       1.395
# 知识创新           0.0549      0.051      1.068      0.286      -0.046       0.156
# 创新学习          -0.0339      0.048     -0.701      0.483      -0.129       0.061
# 同侪关系           0.1473      0.057      2.600      0.009       0.036       0.258
# ==============================================================================
# Omnibus:                       78.315   Durbin-Watson:                   1.608
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              237.693
# Skew:                           0.286   Prob(JB):                     2.43e-52
# Kurtosis:                       5.104   Cond. No.                         329.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
