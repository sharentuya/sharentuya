# %%
import mytools
import pandas as pd

# %%
数据表 = mytools.读取SPSS数据文件(R'data\国家认同数据清理后.sav')

# %%
import pandas as pd
file_path_excel =( R'data\国家认同数据清理后.xlsx')
df_excel = pd.read_excel(file_path_excel)
# 创建年级、政治面貌你愿意加入其他国籍吗的交互表
cross_tab = pd.crosstab(index=[df_excel['年级'], df_excel['发展信心']], 
                        columns=df_excel['政治面貌'], 
                        margins=True,normalize=True)  # All 行和列的总和

cross_tab
# Out:
# 政治面貌               1         2         3         4       All
# 年级  发展信心
# 0   1       0.006418  0.000000  0.000000  0.000000  0.006418
#     2       0.001284  0.000000  0.000000  0.000000  0.001284
#     3       0.001284  0.000000  0.000000  0.000000  0.001284
#     4       0.006418  0.000000  0.001284  0.000000  0.007702
# 1   1       0.019255  0.001284  0.002567  0.000000  0.023107
#     2       0.006418  0.000000  0.000000  0.001284  0.007702
#     3       0.080873  0.006418  0.012837  0.001284  0.101412
#     4       0.184852  0.007702  0.017972  0.001284  0.211810
# 2   1       0.011553  0.000000  0.003851  0.000000  0.015404
#     2       0.010270  0.008986  0.002567  0.000000  0.021823
#     3       0.086008  0.008986  0.014121  0.001284  0.110398
#     4       0.137356  0.016688  0.012837  0.005135  0.172015
# 3   1       0.011553  0.005135  0.001284  0.000000  0.017972
#     2       0.006418  0.000000  0.006418  0.000000  0.012837
#     3       0.034660  0.016688  0.014121  0.005135  0.070603
#     4       0.057766  0.034660  0.006418  0.005135  0.103979
#     #NULL!  0.001284  0.000000  0.000000  0.000000  0.001284
# 4   1       0.001284  0.001284  0.002567  0.000000  0.005135
#     2       0.001284  0.000000  0.000000  0.000000  0.001284
#     3       0.024390  0.008986  0.006418  0.000000  0.039795
#     4       0.046213  0.015404  0.005135  0.000000  0.066752
# All         0.736842  0.132221  0.110398  0.020539  1.000000

# %%
from scipy import stats
# 假设我们关注的是第二年级的学生（假设年级用数字“2”表示）
specific_grade = "大二"

# 筛选出特定年级的数据
df_specific_grade = 数据表[数据表['年级'] == specific_grade]

# 创建政治面貌和会打多少分的交互表
cross_tab_specific_grade = pd.crosstab(df_specific_grade['世博会'], df_specific_grade['中国传统文化'])

# 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)

print(chi2_grade,p_grade)
cross_tab_specific_grade
# Out:
# 16.03309045031239 0.013577455672404723
# 中国传统文化  古板，跟不上潮流  比较肯定  富有内涵，意义深刻
# 世博会
# 没感觉            0     3          4
# 一般             3     9         19
# 比较好            0    26         48
# 感到自豪           3    27        107

# %%
mytools.两个无序类别变量的统计分析(df_specific_grade,'世博会','中国传统文化')
# Out:
# tau_y系数: 0.0286 极弱相关或无相关
# --------  -  --  ---
# 没感觉    0   3    4
# 一般      3   9   19
# 比较好    0  26   48
# 感到自豪  3  27  107
# --------  -  --  ---
# 卡方值： 16.03, p值： 0.0136,自由度:6。
# 拒绝虚无假设

# %%
import pandas as pd
file_path_excel = R'data\国家认同数据清理后.xlsx'

# %%
df_excel = pd.read_excel(file_path_excel)
# 创建年级、政治面貌和会打多少分的交互表
cross_tab = pd.crosstab(index=[df_excel['年级'], df_excel['会打多少分']], 
                        columns=df_excel['政治面貌'], 
                        margins=True, normalize=True)  # All 行和列的总和

# %%
from scipy import stats
# 假设我们关注的是第一年级的学生（假设年级用数字“2”表示）
specific_grade = 1

# 筛选出特定年级的数据
df_specific_grade = df_excel[df_excel['年级'] == specific_grade]

# 创建政治面貌和会打多少分的交互表
cross_tab_specific_grade = pd.crosstab(df_specific_grade['你愿意加入其他国籍吗'], df_specific_grade['政治面貌'],
                                        margins=True, normalize=True)
                                    
# 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)

print(chi2_grade,p_grade)
cross_tab_specific_grade
# Out:
# 0.05546303490024435 1.0
# 政治面貌               1         2         3         4       All
# 你愿意加入其他国籍吗
# 1           0.026119  0.000000  0.011194  0.000000  0.037313
# 2           0.354478  0.011194  0.033582  0.007463  0.406716
# 3           0.216418  0.026119  0.014925  0.003731  0.261194
# 4           0.250000  0.007463  0.037313  0.000000  0.294776
# All         0.847015  0.044776  0.097015  0.011194  1.000000

# %%
# 创建政治面貌和会打多少分的交互表
cross_tab_specific_grade = pd.crosstab(df_excel['你愿意加入其他国籍吗'], df_excel['政治面貌'])

# 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)
print(chi2_grade, p_grade)
# Out:
# 14.05815259055835 0.29701018402924734
